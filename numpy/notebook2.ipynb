# %% [markdown]
# ## Imports

# %%
import re
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from data import Data
from layers import DenseLayer
from activation import ReLUActivation, SoftmaxActivation
from neuralnet import NeuralNetwork
from losses import CategoricalCrossEntropy
from metrics import accuracy

# %% [markdown]
# ## Ler os datasets

# %%
train_df = pd.read_csv("../dataset_final.csv", sep=";")
test_df = pd.read_csv("../subm1.csv", sep=";")

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

display(train_df.head())
display(test_df.head())
# Out:
# Train shape: (6998, 3)
# Test shape: (150, 2)
#         ID                                               Text      Label
# 0  D1-0001  Photocatalytic water splitting uses semiconduc...  Anthropic
# 1  D1-0002  Placental pathology provides critical informat...  Anthropic
# 2  D1-0003  Surgical pathology involves the examination of...       Meta
# 3  D1-0004  The configuration space network (CSN) of a dyn...      Human
# 4  D1-0005  The pathology of aging focuses on the biologic...       Meta
#      ID                                               Text
# 0  D2-1  A covalent bond is a chemical bond that involv...
# 1  D2-2  A covalent bond forms when two atoms share one...
# 2  D2-3  A covalent bond is a type of chemical bond whe...
# 3  D2-4  A covalent bond is a chemical bond that involv...
# 4  D2-5  Driven by exciting developments in the field o...

# %% [markdown]
# ## Limpeza de texto

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text



cleanText=False ####################################### mudar 

if cleanText:
    train_df["clean_text"] = train_df["Text"].apply(clean_text)
    test_df["clean_text"] = test_df["Text"].apply(clean_text)
    print("com texto limpo")
else:
    train_df["clean_text"] = train_df["Text"]
    test_df["clean_text"] = test_df["Text"]
    print("sem texto limpo")

display(train_df[["Text", "clean_text", "Label"]].head())
# Out:
# sem texto limpo
#                                                 Text  \
# 0  Photocatalytic water splitting uses semiconduc...
# 1  Placental pathology provides critical informat...
# 2  Surgical pathology involves the examination of...
# 3  The configuration space network (CSN) of a dyn...
# 4  The pathology of aging focuses on the biologic...
#
#                                           clean_text      Label
# 0  Photocatalytic water splitting uses semiconduc...  Anthropic
# 1  Placental pathology provides critical informat...  Anthropic
# 2  Surgical pathology involves the examination of...       Meta
# 3  The configuration space network (CSN) of a dyn...      Human
# 4  The pathology of aging focuses on the biologic...       Meta

# %% [markdown]
# ## Ver classes

# %%
print("Classes:")
print(train_df["Label"].value_counts())
# Out:
# Classes:
# Label
# OpenAI       1583
# Google       1582
# Meta         1544
# Anthropic    1397
# Human         892
# Name: count, dtype: int64

# %% [markdown]
# ## Construir vocabulário
#
# Bag of Words

# %%
def build_vocab(texts, max_features=5000, min_freq=2):
    counter = Counter()
    
    for text in texts:
        counter.update(text.split())
    
    vocab_items = [
        word for word, freq in counter.items()
        if freq >= min_freq
    ]
    
    vocab_items = sorted(
        vocab_items,
        key=lambda word: counter[word],
        reverse=True
    )[:max_features]
    
    vocab = {word: idx for idx, word in enumerate(vocab_items)}
    return vocab

# %% [markdown]
# ## Transformar texto em Bag of Words

# %%
def text_to_bow(texts, vocab):
    X = np.zeros((len(texts), len(vocab)), dtype=np.float32)
    
    for i, text in enumerate(texts):
        for word in text.split():
            if word in vocab:
                X[i, vocab[word]] += 1.0
                
    return X

# %% [markdown]
# ## Transformar texto em TFIDF

# %%
def compute_idf(texts, vocab):
    n_docs = len(texts)
    df = np.zeros(len(vocab), dtype=np.float32)

    for text in texts:
        seen_words = set()
        for word in text.split():
            if word in vocab and word not in seen_words:
                df[vocab[word]] += 1
                seen_words.add(word)

    idf = np.log((n_docs + 1) / (df + 1)) + 1
    return idf

def text_to_tfidf(texts, vocab, idf):
    X = np.zeros((len(texts), len(vocab)), dtype=np.float32)

    for i, text in enumerate(texts):
        words = text.split()
        if len(words) == 0:
            continue

        for word in words:
            if word in vocab:
                X[i, vocab[word]] += 1.0

        X[i] = X[i] / len(words)
        X[i] = X[i] * idf

        # normalização L2 (melhora bastante)
        norm = np.linalg.norm(X[i])
        if norm > 0:
            X[i] = X[i] / norm


    return X

# %% [markdown]
# ## Codificar labels

# %%
def fit_label_encoder(labels):
    classes = sorted(labels.unique())
    label_to_idx = {label: i for i, label in enumerate(classes)}
    idx_to_label = {i: label for label, i in label_to_idx.items()}
    return label_to_idx, idx_to_label

def encode_labels(labels, label_to_idx):
    return np.array([label_to_idx[label] for label in labels], dtype=np.int32)

def one_hot_encode(y, num_classes):
    y_onehot = np.zeros((len(y), num_classes), dtype=np.float32)
    y_onehot[np.arange(len(y)), y] = 1.0
    return y_onehot

# %% [markdown]
# ## Split treino / validação

# %%
def train_val_split(X, y, val_size=0.2, seed=42):
    np.random.seed(seed)
    indices = np.arange(len(X))
    np.random.shuffle(indices)
    
    split_idx = int(len(X) * (1 - val_size))
    train_idx = indices[:split_idx]
    val_idx = indices[split_idx:]
    
    return X[train_idx], X[val_idx], y[train_idx], y[val_idx]

texts = train_df["clean_text"].to_numpy()
labels = train_df["Label"].to_numpy()

X_train_text, X_val_text, y_train, y_val = train_val_split(texts, labels, val_size=0.2, seed=42)

print("X_train:", X_train_text.shape)
print("X_val:", X_val_text.shape)
print("y_train:", y_train.shape)
print("y_val:", y_val.shape)
# Out:
# X_train: (5598,)
# X_val: (1400,)
# y_train: (5598,)
# y_val: (1400,)

# %%
vocab = build_vocab(X_train_text)

print("Vocabulary size:", len(vocab))
print("Primeiras 20 palavras:", list(vocab.keys())[:20])
# Out:
# Vocabulary size: 5000
# Primeiras 20 palavras: ['the', 'and', 'of', 'to', 'a', 'in', 'is', 'for', 'that', 'are', 'as', 'The', 'by', 'or', 'with', 'on', 'from', 'This', 'which', 'such']

# %%
USE_TFIDF = False ############################ mudar 

if USE_TFIDF:
    idf = compute_idf(X_train_text, vocab)
    
    X_train = text_to_tfidf(X_train_text, vocab, idf)
    X_val = text_to_tfidf(X_val_text, vocab, idf)
    X_test_final = text_to_tfidf(test_df["clean_text"], vocab, idf)

else:
    X_train = text_to_bow(X_train_text, vocab)
    X_val = text_to_bow(X_val_text, vocab)
    X_test_final = text_to_bow(test_df["clean_text"], vocab)

print("X_train:", X_train.shape)
print("X_val:", X_val.shape)
print("X_test_final:", X_test_final.shape)



label_to_idx, idx_to_label = fit_label_encoder(train_df["Label"])

y_train_idx = encode_labels(y_train, label_to_idx)
y_val_idx = encode_labels(y_val, label_to_idx)

num_classes = len(label_to_idx)
y_train = one_hot_encode(y_train_idx, num_classes)
y_val = one_hot_encode(y_val_idx, num_classes)

print("Classes:", label_to_idx)
print("y_val shape:", y_val.shape)
# Out:
# X_train: (5598, 5000)
# X_val: (1400, 5000)
# X_test_final: (150, 5000)
# Classes: {'Anthropic': 0, 'Google': 1, 'Human': 2, 'Meta': 3, 'OpenAI': 4}
# y_val shape: (1400, 5)

# %% [markdown]
# ## Criar objetos Data

# %%
train_data = Data(X_train, y_train)
val_data = Data(X_val, y_val)
test_data = Data(X_test_final, y=None)

# %% [markdown]
# ## Baseline — Logistic Regression multi-classe

# %%
logreg = NeuralNetwork(
    epochs=150,
    batch_size=32,
    learning_rate=0.05,
    momentum=0.9,
    verbose=True,
    loss=CategoricalCrossEntropy,
    metric=accuracy
)
val_pred_logreg = logreg.predict(val_data)
val_acc_logreg = accuracy(y_val, val_pred_logreg)

print("Validation accuracy - Logistic Regression:", val_acc_logreg)

logreg.add(DenseLayer(num_classes, input_shape=(X_train.shape[1],)))
logreg.add(SoftmaxActivation())

logreg.fit(train_data, val_dataset=val_data, early_stopping=True, patience=5)
# Out:
# Validation accuracy - Logistic Regression: 0.12928571428571428
# Epoch 1/500 - loss: 2.5209 - acc: 0.3599 - val_loss: 1.9317 - val_acc: 0.4614
# Epoch 2/500 - loss: 1.6864 - acc: 0.5046 - val_loss: 1.5935 - val_acc: 0.5350
# Epoch 3/500 - loss: 1.3607 - acc: 0.5729 - val_loss: 1.4125 - val_acc: 0.5586
# Epoch 4/500 - loss: 1.1457 - acc: 0.6243 - val_loss: 1.2651 - val_acc: 0.5929
# Epoch 5/500 - loss: 0.9832 - acc: 0.6663 - val_loss: 1.1810 - val_acc: 0.6200
# Epoch 6/500 - loss: 0.8653 - acc: 0.7015 - val_loss: 1.0890 - val_acc: 0.6429
# Epoch 7/500 - loss: 0.7745 - acc: 0.7279 - val_loss: 1.0360 - val_acc: 0.6543
# Epoch 8/500 - loss: 0.6939 - acc: 0.7524 - val_loss: 0.9779 - val_acc: 0.6686
# Epoch 9/500 - loss: 0.6300 - acc: 0.7735 - val_loss: 0.9479 - val_acc: 0.6800
# Epoch 10/500 - loss: 0.5734 - acc: 0.7917 - val_loss: 0.9044 - val_acc: 0.6857
# Epoch 11/500 - loss: 0.5236 - acc: 0.8058 - val_loss: 0.8864 - val_acc: 0.7000
# Epoch 12/500 - loss: 0.4828 - acc: 0.8232 - val_loss: 0.8481 - val_acc: 0.7057
# Epoch 13/500 - loss: 0.4466 - acc: 0.8342 - val_loss: 0.8308 - val_acc: 0.7143
# Epoch 14/500 - loss: 0.4145 - acc: 0.8460 - val_loss: 0.8121 - val_acc: 0.7164
# Epoch 15/500 - loss: 0.3864 - acc: 0.8608 - val_loss: 0.7851 - val_acc: 0.7250
# Epoch 16/500 - loss: 0.3619 - acc: 0.8716 - val_loss: 0.7687 - val_acc: 0.7329
# Epoch 17/500 - loss: 0.3412 - acc: 0.8805 - val_loss: 0.7546 - val_acc: 0.7379
# Epoch 18/500 - loss: 0.3179 - acc: 0.8885 - val_loss: 0.7487 - val_acc: 0.7407
# Epoch 19/500 - loss: 0.2994 - acc: 0.8967 - val_loss: 0.7405 - val_acc: 0.7507
# Epoch 20/500 - loss: 0.2854 - acc: 0.9057 - val_loss: 0.7213 - val_acc: 0.7479
# Epoch 21/500 - loss: 0.2705 - acc: 0.9091 - val_loss: 0.7130 - val_acc: 0.7479
# Epoch 22/500 - loss: 0.2534 - acc: 0.9184 - val_loss: 0.7150 - val_acc: 0.7500
# Epoch 23/500 - loss: 0.2424 - acc: 0.9227 - val_loss: 0.6917 - val_acc: 0.7536
# Epoch 24/500 - loss: 0.2285 - acc: 0.9294 - val_loss: 0.6866 - val_acc: 0.7614
# Epoch 25/500 - loss: 0.2176 - acc: 0.9346 - val_loss: 0.6776 - val_acc: 0.7600
# Epoch 26/500 - loss: 0.2080 - acc: 0.9387 - val_loss: 0.6769 - val_acc: 0.7614
# Epoch 27/500 - loss: 0.2003 - acc: 0.9430 - val_loss: 0.6672 - val_acc: 0.7664
# Epoch 28/500 - loss: 0.1907 - acc: 0.9471 - val_loss: 0.6682 - val_acc: 0.7621
# Epoch 29/500 - loss: 0.1822 - acc: 0.9536 - val_loss: 0.6560 - val_acc: 0.7686
# Epoch 30/500 - loss: 0.1754 - acc: 0.9573 - val_loss: 0.6513 - val_acc: 0.7686
# Epoch 31/500 - loss: 0.1684 - acc: 0.9591 - val_loss: 0.6426 - val_acc: 0.7757
# Epoch 32/500 - loss: 0.1610 - acc: 0.9637 - val_loss: 0.6405 - val_acc: 0.7707
# Epoch 33/500 - loss: 0.1566 - acc: 0.9653 - val_loss: 0.6371 - val_acc: 0.7757
# Epoch 34/500 - loss: 0.1500 - acc: 0.9695 - val_loss: 0.6358 - val_acc: 0.7800
# Epoch 35/500 - loss: 0.1450 - acc: 0.9702 - val_loss: 0.6324 - val_acc: 0.7729
# Epoch 36/500 - loss: 0.1392 - acc: 0.9752 - val_loss: 0.6258 - val_acc: 0.7764
# Epoch 37/500 - loss: 0.1351 - acc: 0.9752 - val_loss: 0.6214 - val_acc: 0.7779
# Epoch 38/500 - loss: 0.1306 - acc: 0.9773 - val_loss: 0.6160 - val_acc: 0.7779
# Epoch 39/500 - loss: 0.1260 - acc: 0.9793 - val_loss: 0.6194 - val_acc: 0.7779
# Epoch 40/500 - loss: 0.1218 - acc: 0.9809 - val_loss: 0.6152 - val_acc: 0.7807
# Epoch 41/500 - loss: 0.1192 - acc: 0.9812 - val_loss: 0.6122 - val_acc: 0.7800
# Epoch 42/500 - loss: 0.1148 - acc: 0.9841 - val_loss: 0.6060 - val_acc: 0.7836
# Epoch 43/500 - loss: 0.1122 - acc: 0.9841 - val_loss: 0.6069 - val_acc: 0.7850
# Epoch 44/500 - loss: 0.1086 - acc: 0.9852 - val_loss: 0.6004 - val_acc: 0.7843
# Epoch 45/500 - loss: 0.1053 - acc: 0.9873 - val_loss: 0.5986 - val_acc: 0.7864
# Epoch 46/500 - loss: 0.1027 - acc: 0.9882 - val_loss: 0.5956 - val_acc: 0.7871
# Epoch 47/500 - loss: 0.0998 - acc: 0.9900 - val_loss: 0.5950 - val_acc: 0.7893
# Epoch 48/500 - loss: 0.0968 - acc: 0.9905 - val_loss: 0.5941 - val_acc: 0.7914
# Epoch 49/500 - loss: 0.0947 - acc: 0.9911 - val_loss: 0.5946 - val_acc: 0.7921
# Epoch 50/500 - loss: 0.0923 - acc: 0.9912 - val_loss: 0.5890 - val_acc: 0.7893
# Epoch 51/500 - loss: 0.0903 - acc: 0.9923 - val_loss: 0.5868 - val_acc: 0.7921
# Epoch 52/500 - loss: 0.0878 - acc: 0.9930 - val_loss: 0.5867 - val_acc: 0.7950
# Epoch 53/500 - loss: 0.0858 - acc: 0.9945 - val_loss: 0.5832 - val_acc: 0.7964
# Epoch 54/500 - loss: 0.0838 - acc: 0.9948 - val_loss: 0.5813 - val_acc: 0.7964
# Epoch 55/500 - loss: 0.0818 - acc: 0.9937 - val_loss: 0.5835 - val_acc: 0.7993
# Epoch 56/500 - loss: 0.0804 - acc: 0.9945 - val_loss: 0.5767 - val_acc: 0.7964
# Epoch 57/500 - loss: 0.0783 - acc: 0.9954 - val_loss: 0.5771 - val_acc: 0.7993
# Epoch 58/500 - loss: 0.0765 - acc: 0.9962 - val_loss: 0.5776 - val_acc: 0.8021
# Epoch 59/500 - loss: 0.0753 - acc: 0.9959 - val_loss: 0.5730 - val_acc: 0.7993
# Epoch 60/500 - loss: 0.0735 - acc: 0.9961 - val_loss: 0.5793 - val_acc: 0.7957
# Epoch 61/500 - loss: 0.0720 - acc: 0.9964 - val_loss: 0.5721 - val_acc: 0.8014
# Epoch 62/500 - loss: 0.0706 - acc: 0.9973 - val_loss: 0.5685 - val_acc: 0.8043
# Epoch 63/500 - loss: 0.0693 - acc: 0.9966 - val_loss: 0.5727 - val_acc: 0.7986
# Epoch 64/500 - loss: 0.0681 - acc: 0.9977 - val_loss: 0.5666 - val_acc: 0.8021
# Epoch 65/500 - loss: 0.0665 - acc: 0.9973 - val_loss: 0.5664 - val_acc: 0.8007
# Epoch 66/500 - loss: 0.0654 - acc: 0.9973 - val_loss: 0.5679 - val_acc: 0.8014
# Epoch 67/500 - loss: 0.0640 - acc: 0.9980 - val_loss: 0.5628 - val_acc: 0.8029
# Epoch 68/500 - loss: 0.0629 - acc: 0.9984 - val_loss: 0.5633 - val_acc: 0.8057
# Epoch 69/500 - loss: 0.0619 - acc: 0.9982 - val_loss: 0.5624 - val_acc: 0.8036
# Epoch 70/500 - loss: 0.0608 - acc: 0.9987 - val_loss: 0.5600 - val_acc: 0.8064
# Epoch 71/500 - loss: 0.0599 - acc: 0.9986 - val_loss: 0.5614 - val_acc: 0.8043
# Epoch 72/500 - loss: 0.0588 - acc: 0.9987 - val_loss: 0.5599 - val_acc: 0.8043
# Epoch 73/500 - loss: 0.0578 - acc: 0.9991 - val_loss: 0.5627 - val_acc: 0.8057
# Epoch 74/500 - loss: 0.0571 - acc: 0.9989 - val_loss: 0.5554 - val_acc: 0.8064
# Epoch 75/500 - loss: 0.0560 - acc: 0.9986 - val_loss: 0.5554 - val_acc: 0.8043
# Epoch 76/500 - loss: 0.0552 - acc: 0.9991 - val_loss: 0.5542 - val_acc: 0.8057
# Epoch 77/500 - loss: 0.0544 - acc: 0.9989 - val_loss: 0.5564 - val_acc: 0.8064
# Epoch 78/500 - loss: 0.0535 - acc: 0.9993 - val_loss: 0.5560 - val_acc: 0.8050
# Epoch 79/500 - loss: 0.0527 - acc: 0.9993 - val_loss: 0.5524 - val_acc: 0.8086
# Epoch 80/500 - loss: 0.0520 - acc: 0.9991 - val_loss: 0.5535 - val_acc: 0.8093
# Epoch 81/500 - loss: 0.0512 - acc: 0.9993 - val_loss: 0.5496 - val_acc: 0.8114
# Epoch 82/500 - loss: 0.0504 - acc: 0.9993 - val_loss: 0.5506 - val_acc: 0.8064
# Epoch 83/500 - loss: 0.0496 - acc: 0.9993 - val_loss: 0.5485 - val_acc: 0.8100
# Epoch 84/500 - loss: 0.0490 - acc: 0.9993 - val_loss: 0.5481 - val_acc: 0.8100
# Epoch 85/500 - loss: 0.0484 - acc: 0.9993 - val_loss: 0.5477 - val_acc: 0.8071
# Epoch 86/500 - loss: 0.0477 - acc: 0.9995 - val_loss: 0.5461 - val_acc: 0.8079
# Epoch 87/500 - loss: 0.0469 - acc: 0.9995 - val_loss: 0.5450 - val_acc: 0.8121
# Epoch 88/500 - loss: 0.0463 - acc: 0.9995 - val_loss: 0.5503 - val_acc: 0.8107
# Epoch 89/500 - loss: 0.0458 - acc: 0.9995 - val_loss: 0.5445 - val_acc: 0.8086
# Epoch 90/500 - loss: 0.0452 - acc: 0.9993 - val_loss: 0.5454 - val_acc: 0.8071
# Epoch 91/500 - loss: 0.0446 - acc: 0.9995 - val_loss: 0.5428 - val_acc: 0.8107
# Epoch 92/500 - loss: 0.0441 - acc: 0.9995 - val_loss: 0.5438 - val_acc: 0.8086
# Epoch 93/500 - loss: 0.0434 - acc: 0.9995 - val_loss: 0.5420 - val_acc: 0.8100
# Epoch 94/500 - loss: 0.0430 - acc: 0.9995 - val_loss: 0.5424 - val_acc: 0.8086
# Epoch 95/500 - loss: 0.0424 - acc: 0.9995 - val_loss: 0.5420 - val_acc: 0.8100
# Epoch 96/500 - loss: 0.0419 - acc: 0.9995 - val_loss: 0.5406 - val_acc: 0.8086
# Epoch 97/500 - loss: 0.0414 - acc: 0.9996 - val_loss: 0.5407 - val_acc: 0.8086
# Epoch 98/500 - loss: 0.0409 - acc: 0.9998 - val_loss: 0.5409 - val_acc: 0.8114
# Epoch 99/500 - loss: 0.0405 - acc: 0.9998 - val_loss: 0.5382 - val_acc: 0.8107
# Epoch 100/500 - loss: 0.0400 - acc: 0.9996 - val_loss: 0.5384 - val_acc: 0.8107
# Epoch 101/500 - loss: 0.0396 - acc: 1.0000 - val_loss: 0.5402 - val_acc: 0.8143
# Epoch 102/500 - loss: 0.0392 - acc: 1.0000 - val_loss: 0.5365 - val_acc: 0.8107
# Epoch 103/500 - loss: 0.0387 - acc: 0.9998 - val_loss: 0.5356 - val_acc: 0.8121
# Epoch 104/500 - loss: 0.0384 - acc: 0.9998 - val_loss: 0.5379 - val_acc: 0.8143
# Epoch 105/500 - loss: 0.0378 - acc: 1.0000 - val_loss: 0.5345 - val_acc: 0.8129
# Epoch 106/500 - loss: 0.0375 - acc: 1.0000 - val_loss: 0.5357 - val_acc: 0.8121
# Epoch 107/500 - loss: 0.0370 - acc: 1.0000 - val_loss: 0.5337 - val_acc: 0.8114
# Epoch 108/500 - loss: 0.0367 - acc: 1.0000 - val_loss: 0.5333 - val_acc: 0.8121
# Epoch 109/500 - loss: 0.0365 - acc: 1.0000 - val_loss: 0.5327 - val_acc: 0.8121
# Epoch 110/500 - loss: 0.0360 - acc: 1.0000 - val_loss: 0.5340 - val_acc: 0.8114
# Epoch 111/500 - loss: 0.0357 - acc: 1.0000 - val_loss: 0.5371 - val_acc: 0.8171
# Epoch 112/500 - loss: 0.0353 - acc: 1.0000 - val_loss: 0.5325 - val_acc: 0.8157
# Epoch 113/500 - loss: 0.0349 - acc: 1.0000 - val_loss: 0.5314 - val_acc: 0.8136
# Epoch 114/500 - loss: 0.0345 - acc: 1.0000 - val_loss: 0.5310 - val_acc: 0.8150
# Epoch 115/500 - loss: 0.0342 - acc: 1.0000 - val_loss: 0.5320 - val_acc: 0.8157
# Epoch 116/500 - loss: 0.0339 - acc: 1.0000 - val_loss: 0.5310 - val_acc: 0.8171
# Epoch 117/500 - loss: 0.0335 - acc: 1.0000 - val_loss: 0.5311 - val_acc: 0.8143
# Epoch 118/500 - loss: 0.0333 - acc: 1.0000 - val_loss: 0.5308 - val_acc: 0.8150
# Epoch 119/500 - loss: 0.0329 - acc: 1.0000 - val_loss: 0.5301 - val_acc: 0.8171
# Epoch 120/500 - loss: 0.0326 - acc: 1.0000 - val_loss: 0.5282 - val_acc: 0.8143
# Epoch 121/500 - loss: 0.0324 - acc: 1.0000 - val_loss: 0.5290 - val_acc: 0.8164
# Epoch 122/500 - loss: 0.0321 - acc: 1.0000 - val_loss: 0.5285 - val_acc: 0.8179
# Epoch 123/500 - loss: 0.0319 - acc: 1.0000 - val_loss: 0.5281 - val_acc: 0.8136
# Epoch 124/500 - loss: 0.0316 - acc: 1.0000 - val_loss: 0.5281 - val_acc: 0.8193
# Epoch 125/500 - loss: 0.0313 - acc: 1.0000 - val_loss: 0.5277 - val_acc: 0.8179
# Epoch 126/500 - loss: 0.0310 - acc: 1.0000 - val_loss: 0.5264 - val_acc: 0.8193
# Epoch 127/500 - loss: 0.0307 - acc: 1.0000 - val_loss: 0.5261 - val_acc: 0.8179
# Epoch 128/500 - loss: 0.0304 - acc: 1.0000 - val_loss: 0.5277 - val_acc: 0.8164
# Epoch 129/500 - loss: 0.0303 - acc: 1.0000 - val_loss: 0.5259 - val_acc: 0.8193
# Epoch 130/500 - loss: 0.0299 - acc: 1.0000 - val_loss: 0.5283 - val_acc: 0.8186
# Epoch 131/500 - loss: 0.0297 - acc: 1.0000 - val_loss: 0.5248 - val_acc: 0.8186
# Epoch 132/500 - loss: 0.0294 - acc: 1.0000 - val_loss: 0.5254 - val_acc: 0.8200
# Epoch 133/500 - loss: 0.0292 - acc: 1.0000 - val_loss: 0.5253 - val_acc: 0.8200
# Epoch 134/500 - loss: 0.0289 - acc: 1.0000 - val_loss: 0.5232 - val_acc: 0.8179
# Epoch 135/500 - loss: 0.0288 - acc: 1.0000 - val_loss: 0.5232 - val_acc: 0.8179
# Epoch 136/500 - loss: 0.0285 - acc: 1.0000 - val_loss: 0.5247 - val_acc: 0.8179
# Epoch 137/500 - loss: 0.0283 - acc: 1.0000 - val_loss: 0.5230 - val_acc: 0.8179
# Epoch 138/500 - loss: 0.0281 - acc: 1.0000 - val_loss: 0.5224 - val_acc: 0.8186
# Epoch 139/500 - loss: 0.0279 - acc: 1.0000 - val_loss: 0.5227 - val_acc: 0.8207
# Epoch 140/500 - loss: 0.0276 - acc: 1.0000 - val_loss: 0.5224 - val_acc: 0.8186
# Epoch 141/500 - loss: 0.0274 - acc: 1.0000 - val_loss: 0.5227 - val_acc: 0.8214
# Epoch 142/500 - loss: 0.0272 - acc: 1.0000 - val_loss: 0.5224 - val_acc: 0.8214
# Epoch 143/500 - loss: 0.0270 - acc: 1.0000 - val_loss: 0.5224 - val_acc: 0.8164
# Early stopping at epoch 143

# %% [markdown]
# ## Avaliar baseline no conjunto de validação

# %%
val_pred_logreg = logreg.predict(val_data)
val_acc_logreg = accuracy(y_val, val_pred_logreg)

print("Validation accuracy - Logistic Regression:", val_acc_logreg)
# Out:
# Validation accuracy - Logistic Regression: 0.8185714285714286

# %% [markdown]
# ## Ver evolução do treino do baseline

# %%
epochs_logreg = list(logreg.history.keys())
losses_logreg = [logreg.history[e]["loss"] for e in epochs_logreg]
metrics_logreg = [logreg.history[e]["metric"] for e in epochs_logreg]
val_losses_logreg = [logreg.history[e]["val_loss"] for e in epochs_logreg]
val_metrics_logreg = [logreg.history[e]["val_metric"] for e in epochs_logreg]

plt.figure(figsize=(8, 4))
plt.plot(epochs_logreg, losses_logreg, label= "Train Loss")
plt.plot(epochs_logreg, val_losses_logreg, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Logistic Regression")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(epochs_logreg, metrics_logreg, label="Train Accuracy")
plt.plot(epochs_logreg, val_metrics_logreg, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Logistic Regression")
plt.show()

# %% [markdown]
# ## DNN multi-classe

# %%
dnn = NeuralNetwork(
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    momentum=0.9,
    verbose=True,
    loss=CategoricalCrossEntropy,
    metric=accuracy
)

dnn.add(DenseLayer(128, input_shape=(X_train.shape[1],)))
dnn.add(ReLUActivation())
dnn.add(DenseLayer(64))
dnn.add(ReLUActivation())
dnn.add(DenseLayer(num_classes))
dnn.add(SoftmaxActivation())

dnn.fit(train_data, val_dataset=val_data, early_stopping=True, patience=5)
# Out:
# Epoch 1/50 - loss: 2.0255 - acc: 0.3728 - val_loss: 1.3287 - val_acc: 0.3979
# Epoch 2/50 - loss: 1.1781 - acc: 0.5025 - val_loss: 1.1529 - val_acc: 0.5214
# Epoch 3/50 - loss: 1.0047 - acc: 0.5807 - val_loss: 1.1346 - val_acc: 0.5329
# Epoch 4/50 - loss: 0.8740 - acc: 0.6393 - val_loss: 1.0946 - val_acc: 0.5550
# Epoch 5/50 - loss: 0.7742 - acc: 0.6952 - val_loss: 1.0314 - val_acc: 0.5750
# Epoch 6/50 - loss: 0.6806 - acc: 0.7249 - val_loss: 1.0407 - val_acc: 0.5921
# Epoch 7/50 - loss: 0.5991 - acc: 0.7653 - val_loss: 1.0400 - val_acc: 0.6200
# Epoch 8/50 - loss: 0.5122 - acc: 0.7997 - val_loss: 1.0489 - val_acc: 0.6250
# Epoch 9/50 - loss: 0.4370 - acc: 0.8314 - val_loss: 1.0664 - val_acc: 0.6207
# Epoch 10/50 - loss: 0.3702 - acc: 0.8617 - val_loss: 1.1416 - val_acc: 0.6257
# Early stopping at epoch 10

# %% [markdown]
# ## Avaliar DNN

# %%
val_pred_dnn = dnn.predict(val_data)
val_acc_dnn = accuracy(y_val, val_pred_dnn)

print("Validation accuracy - DNN:", val_acc_dnn)
# Out:
# Validation accuracy - DNN: 0.575

# %% [markdown]
# ## Ver evolução do treino da DNN

# %%
epochs_dnn = list(dnn.history.keys())
losses_dnn = [dnn.history[e]["loss"] for e in epochs_dnn]
metrics_dnn = [dnn.history[e]["metric"] for e in epochs_dnn]
val_losses_dnn = [dnn.history[e]["val_loss"] for e in epochs_dnn]
val_metrics_dnn = [dnn.history[e]["val_metric"] for e in epochs_dnn]

plt.figure(figsize=(8, 4))
plt.plot(epochs_dnn, losses_dnn)
plt.plot(epochs_dnn, losses_dnn, label= "Train Loss")
plt.plot(epochs_dnn, val_losses_dnn, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("DNN - Training Loss")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(epochs_dnn, metrics_dnn)
plt.plot(epochs_dnn, metrics_dnn, label="Train Accuracy")
plt.plot(epochs_dnn, val_metrics_dnn, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("DNN - Training Accuracy")
plt.show()

# %% [markdown]
# ## Escolher o melhor modelo

# %%
if val_acc_dnn >= val_acc_logreg:
    best_model = dnn
    best_model_name = "DNN"
else:
    best_model = logreg
    best_model_name = "Logistic Regression"

print("Best model:", best_model_name)
# Out:
# Best model: Logistic Regression

# %% [markdown]
# ## Prever o subm1.csv

# %%
test_pred = best_model.predict(test_data)
test_pred_idx = np.argmax(test_pred, axis=1)
test_pred_labels = [idx_to_label[i] for i in test_pred_idx]

print(test_pred_labels[:10])
# Out:
# ['Google', 'Meta', 'Meta', 'Meta', 'Human', 'Anthropic', 'Meta', 'Meta', 'Human', 'Human']

# %% [markdown]
# ## Criar ficheiro de submissão

# %%
submission = pd.DataFrame({
    "ID": test_df["ID"],
    "Label": test_pred_labels
})

display(submission.head())

submission.to_csv("submission.csv", sep=";", index=False)
print("submission.csv guardado com sucesso.")
# Out:
#      ID      Label
# 0  D2-1  Anthropic
# 1  D2-2      Human
# 2  D2-3      Human
# 3  D2-4  Anthropic
# 4  D2-5      Human
# submission.csv guardado com sucesso.

# %% [markdown]
# ## matriz de confusão simples

# %%
def confusion_matrix_numpy(y_true, y_pred, num_classes):
    if y_true.ndim > 1:
        y_true = np.argmax(y_true, axis=1)
    if y_pred.ndim > 1:
        y_pred = np.argmax(y_pred, axis=1)
    
    cm = np.zeros((num_classes, num_classes), dtype=int)
    
    for t, p in zip(y_true, y_pred):
        cm[t, p] += 1
        
    return cm

cm_dnn = confusion_matrix_numpy(y_val, val_pred_dnn, num_classes)
cm_df = pd.DataFrame(
    cm_dnn,
    index=[idx_to_label[i] for i in range(num_classes)],
    columns=[idx_to_label[i] for i in range(num_classes)]
)

display(cm_df)
# Out:
#            Anthropic  Google  Human  Meta  OpenAI
# Anthropic        128      67     17    26      47
# Google            12     250     16    29       6
# Human              6      13    126     3       1
# Meta              30     142      6   133      28
# OpenAI            72      30      4    40     168
